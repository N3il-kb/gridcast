# %%
import os
import requests
import pandas as pd
import numpy as np
import plotly.express as px
import folium
import matplotlib as plt
from prophet import Prophet
import requests

# %%
AGGREGATED_REGIONS = [
    "CAL",
    "CAR",
    "CENT",
    "FLA",
    "MIDA",
    "MIDW",
    "NE",
    "NW",
    "NY",
    "SE",
    "SW",
    "TEN",
    "TEX",
    "US48",
]

EIA_API_KEY = os.getenv("EIA_API_KEY")
if not EIA_API_KEY:
    raise EnvironmentError("Please set your EIA_API_KEY environment variable.")

url = "https://api.eia.gov/v2/electricity/rto/region-data/data/"
params = {
    "api_key": EIA_API_KEY,
    "frequency": "hourly",
    "data[0]": "value",
    "sort[0][column]": "period",
    "sort[0][direction]": "desc",
    "offset": 0,
    "length": 5000,
}
params["facets[respondent][]"] = AGGREGATED_REGIONS

try:
    resp = requests.get(url, params=params)
    resp.raise_for_status()
    data = resp.json()["response"]["data"]
    df = pd.DataFrame(data)
    df.to_csv("eia_hourly_cached.csv", index=False)
except Exception as exc:
    cache_path = "eia_hourly_cached.csv"
    if not os.path.exists(cache_path):
        raise RuntimeError("Failed to download data and no cached file was found.") from exc
    print(f"⚠️ Using cached data because API request failed: {exc}")
    df = pd.read_csv(cache_path)

df["region"] = df["respondent"]
df.head()
# Out:
#           period respondent         respondent-name type  \
# 0  2025-11-14T08        CAL              California   DF
# 1  2025-11-14T08         NW               Northwest   DF
# 2  2025-11-14T08       US48  United States Lower 48   DF
# 3  2025-11-14T07        CAL              California   DF
# 4  2025-11-14T07         NW               Northwest   DF
#
#                    type-name value    value-units region
# 0  Day-ahead demand forecast  1680  megawatthours    CAL
# 1  Day-ahead demand forecast  2177  megawatthours     NW
# 2  Day-ahead demand forecast  3857  megawatthours   US48
# 3  Day-ahead demand forecast  1791  megawatthours    CAL
# 4  Day-ahead demand forecast  2247  megawatthours     NW

# %%
df = df.copy()
df["region"] = df["respondent"]
df["datetime"] = pd.to_datetime(df["period"])
df["demand_MW"] = pd.to_numeric(df["value"], errors="coerce")

latest_idx = df.groupby("region")["datetime"].idxmax()
latest_df = df.loc[latest_idx].copy()
usage = latest_df[["region", "demand_MW", "datetime"]]
latest_time = usage["datetime"].max() # <--Grab the latest data

# %%
# ======================================================
# 2️⃣ Region → state mapping (unchanged)
# ======================================================
region_to_states = {
    "CAL": ["California"],
    "CAR": ["North Carolina", "South Carolina"],
    "CENT": ["Arkansas", "Kansas", "Louisiana", "Missouri", "Nebraska", "Oklahoma"],
    "FLA": ["Florida"],
    "MIDA": ["Delaware", "District of Columbia", "Maryland", "New Jersey", "Pennsylvania", "Virginia", "West Virginia"],
    "MIDW": ["Illinois", "Indiana", "Iowa", "Kentucky", "Michigan", "Minnesota", "North Dakota", "Ohio", "South Dakota", "Wisconsin"],
    "NE": ["Connecticut", "Maine", "Massachusetts", "New Hampshire", "Rhode Island", "Vermont"],
    "NY": ["New York"],
    "NW": ["Idaho", "Montana", "Oregon", "Washington", "Wyoming"],
    "SE": ["Alabama", "Georgia", "Mississippi"],
    "SW": ["Arizona", "Colorado", "New Mexico", "Nevada", "Utah"],
    "TEN": ["Tennessee"],
    "TEX": ["Texas"],
}

usage = usage[usage["region"].isin(region_to_states)].copy()
usage["state_list"] = usage["region"].map(region_to_states)
usage = usage.explode("state_list").rename(columns={"state_list": "state"})

# %%
# ======================================================
# 3️⃣ Choropleth via Folium (OpenStreetMap)
# ======================================================
geo_url = "https://raw.githubusercontent.com/PublicaMundi/MappingAPI/master/data/geojson/us-states.json"

m = folium.Map(location=[39.5, -98.35], zoom_start=4, tiles="CartoDB positron")

choropleth = folium.Choropleth(
    geo_data=geo_url,
    name="Electricity Demand (MW)",
    data=usage,
    columns=["state", "demand_MW"],
    key_on="feature.properties.name",
    fill_color="YlOrRd",
    fill_opacity=0.8,
    line_opacity=0.3,
    nan_fill_color="gray",
    legend_name=f"Electricity Demand (MW) — {latest_time:%Y-%m-%d %H:%M}",
).add_to(m)

# ✅ tooltip must attach to a GeoJson object, not the map
folium.GeoJson(
    geo_url,
    name="State Boundaries",
    tooltip=folium.GeoJsonTooltip(
        fields=["name"],
        aliases=["State:"],
        localize=True
    )
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff94792f1b7853cfb7fcd7cd3526f312 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff94792f1b7853cfb7fcd7cd3526f312&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff94792f1b7853cfb7fcd7cd3526f312 = L.map(
#                 &quot;map_ff94792f1b7853cfb7fcd7cd3526f312&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abb0e218e40ba8f01276758bcdd4db70 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abb0e218e40ba8f01276758bcdd4db70.addTo(map_ff94792f1b7853cfb7fcd7cd3526f312);
#
#
#             var choropleth_72d16e5c6445f2283ab2161eb50c3a98 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_5400d12139c6c2b0d3bbe19ee6b519be_styler(feature) {
#             switch(feature.id) {
#                 case &quot;01&quot;: case &quot;05&quot;: case &quot;13&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;37&quot;: case &quot;40&quot;: case &quot;45&quot;: case &quot;47&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;02&quot;: case &quot;15&quot;: case &quot;72&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;04&quot;: case &quot;06&quot;: case &quot;08&quot;: case &quot;09&quot;: case &quot;12&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;25&quot;: case &quot;30&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;41&quot;: case &quot;44&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;53&quot;: case &quot;56&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;24&quot;: case &quot;34&quot;: case &quot;42&quot;: case &quot;51&quot;: case &quot;54&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;46&quot;: case &quot;55&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5400d12139c6c2b0d3bbe19ee6b519be_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5400d12139c6c2b0d3bbe19ee6b519be = L.geoJson(null, {
#                 onEachFeature: geo_json_5400d12139c6c2b0d3bbe19ee6b519be_onEachFeature,
#
#                 style: geo_json_5400d12139c6c2b0d3bbe19ee6b519be_styler,
#             ...{
# }
#         });
#
#         function geo_json_5400d12139c6c2b0d3bbe19ee6b519be_add (data) {
#             geo_json_5400d12139c6c2b0d3bbe19ee6b519

# %%
def forecast_region_prophet_calibrated(df_region, horizon_hours=24*7, window_days=90):
    # ==== prep ====
    g = (
        df_region.drop_duplicates(subset=["datetime"])
                 .set_index("datetime")["demand_MW"]
                 .asfreq("h").interpolate("time").reset_index()
    )
    dfp = g.rename(columns={"datetime": "ds", "demand_MW": "y"})
    dfp["y"] = dfp["y"].clip(lower=0)

    # optional rolling window (recent data only)
    if window_days is not None:
        cutoff = dfp["ds"].max() - pd.Timedelta(days=window_days)
        dfp = dfp[dfp["ds"] >= cutoff].copy()

    # ==== model (more conservative) ====
    m = Prophet(
    growth="flat",                 # stops the drifting trend
    seasonality_mode="additive",
    daily_seasonality=True,
    weekly_seasonality=True,
    yearly_seasonality=False
    )

    m.add_country_holidays(country_name="US")
    m.fit(dfp)

    # in-sample predictions for bias correction
    ins = m.predict(dfp[["ds"]])
    # recent residual mean (last 7 days)
    lookback = 7*24
    bias = (dfp["y"].iloc[-lookback:] - ins["yhat"].iloc[-lookback:]).mean()

    # forecast
    future = m.make_future_dataframe(periods=horizon_hours, freq="h")
    fcst = m.predict(future).tail(horizon_hours).copy()

    # bias-correct and clamp extremes
    p99 = np.nanpercentile(dfp["y"].values, 99)
    fcst["forecast_MW"] = (fcst["yhat"] + bias).clip(lower=0, upper=p99*1.2)

    return fcst[["ds", "forecast_MW"]]

# %%
forecasts = []
for r, g in df.groupby("region"):
    try:
        yhat = forecast_region_prophet_calibrated(g)
        yhat["region"] = r
        forecasts.append(yhat)
    except Exception as e:
        print(f"⚠️ Prophet failed for {r}: {e}")

forecast_df = pd.concat(forecasts, ignore_index=True)
# Out:
# 02:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:49 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:49 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:49 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:49 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# 02:03:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:50 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: divide by zero encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: overflow encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1418: RuntimeWarning: invalid value encountered in matmul
#   comp = np.matmul(X, beta_c.transpose())
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: divide by zero encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: overflow encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1562: RuntimeWarning: invalid value encountered in matmul
#   Xb_a = np.matmul(seasonal_features.values,
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: divide by zero encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: overflow encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/prophet/forecaster.py:1564: RuntimeWarning: invalid value encountered in matmul
#   Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)

# %%
import matplotlib.pyplot as plt
# Plot
region = "CAL"

actual = (
    df[df["region"] == region]
    .drop_duplicates(subset=["datetime"])  # Ensure no duplicate datetime values
    .set_index("datetime")["demand_MW"]
    .asfreq("H")
    .interpolate()
)
forecast = (
    forecast_df[forecast_df["region"] == region]
    .drop_duplicates(subset=["ds"])  # Ensure no duplicate datetime values
    .set_index("ds")["forecast_MW"]
)

plt.figure(figsize=(12,5))
plt.plot(actual[-7*24:], label="Actual (past week)", color="steelblue")
plt.plot(forecast, label="Forecast (next week)", color="tomato", linestyle="--")
plt.title(f"Electricity Demand Forecast — {region}", fontsize=14)
plt.xlabel("Datetime"); plt.ylabel("Demand (MW)")
plt.legend(); plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/789237376.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")

# %% [markdown]
# ## Datacenter Score

# %%
# ============================
# Compute region-level raw metrics
# ============================

def compute_region_metrics(df_region):
    """Compute raw metrics needed for datacenter scoring."""
    
    # 1. Latest price proxy = latest MW demand
    latest = df_region.drop_duplicates(subset=["datetime"]).sort_values("datetime").iloc[-1]
    price_proxy = latest["demand_MW"]
    
    # 2. Volatility (load variability)
    region_series = (
        df_region.drop_duplicates(subset=["datetime"])
                  .set_index("datetime")["demand_MW"]
                  .asfreq("H")
                  .interpolate()
    )
    volatility = region_series.rolling(24).std().iloc[-1]
    
    # 3. Renewable proxy (EIA fuel mix can be fetched here later)
    # Placeholder → normalized demand as inverse carbon intensity
    renewable_proxy = 1 / (1 + region_series.mean())
    
    # 4. Carbon proxy (inverse of renewables for now)
    carbon_proxy = 1 - renewable_proxy
    
    # package raw
    return {
        "price": price_proxy,
        "volatility": volatility,
        "renewables_proxy": renewable_proxy,
        "carbon_proxy": carbon_proxy
    }

region_raw = {}
for region in usage["region"].unique():
    region_raw[region] = compute_region_metrics(df[df["region"] == region])
# Out:
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")
# /var/folders/h3/f3_68x516pj6d7h2119r5st00000gn/T/ipykernel_57932/3878209777.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .asfreq("H")

# %%
def get_temperature(lat, lon):
    url = (
        f"https://api.open-meteo.com/v1/forecast"
        f"?latitude={lat}&longitude={lon}"
        f"&daily=temperature_2m_mean&past_days=60"
    )
    r = requests.get(url).json()
    temps = r["daily"]["temperature_2m_mean"]
    return float(np.mean(temps))

# %%
def generate_hex_grid(min_lat=25, max_lat=49, min_lon=-124, max_lon=-67, lat_step=1.0, lon_step=1.2):
    points = []
    lat_i = 0

    lat = min_lat
    while lat < max_lat:
        if lat_i % 2 == 0:
            lon = min_lon
        else:
            lon = min_lon + lon_step / 2   # staggered
        
        while lon < max_lon:
            points.append((lat, lon))
            lon += lon_step
        
        lat += lat_step
        lat_i += 1
    
    return points
# Out:
# 1368

# %%
def normalize_series(values):
    arr = np.array(values)
    return (arr - arr.min()) / (arr.max() - arr.min() + 1e-9)

# %%
df_hex = pd.DataFrame([
    {
        "lat": lat,
        "lon": lon,
        **region_raw["CAL"],  # or your region lookup
        "temperature": get_temperature(lat, lon)
    }
    for lat, lon in grid
])

# %%
# normalize everything
norm_cols = ["price", "volatility", "renewables_proxy", "carbon_proxy", "temperature"]
for col in norm_cols:
    df_hex[col + "_norm"] = normalize_series(df_hex[col])
    
# profitability
df_hex["profitability"] = (
    0.4 * (1 - df_hex["price_norm"]) +
    0.3 * (1 - df_hex["volatility_norm"]) +
    0.3 * df_hex["renewables_proxy_norm"]
)

# sustainability
df_hex["sustainability"] = (
    0.35 * df_hex["renewables_proxy_norm"] +
    0.30 * (1 - df_hex["carbon_proxy_norm"]) +
    0.20 * df_hex["temperature_norm"] +
    0.15 * df_hex["renewables_proxy_norm"]
)

# hybrid (default 50/50)
df_hex["hybrid"] = 0.5 * df_hex["profitability"] + 0.5 * df_hex["sustainability"]

# %%
df_hex

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_hex["lon"], df_hex["lat"], c=df_hex["hybrid"], cmap="viridis")
plt.colorbar(label="Hybrid Datacenter Score")
plt.title("Datacenter Score Hex Preview")
plt.show()
