# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
import kagglehub
import os

def load_data():
    # Download from Kaggle
    path = kagglehub.dataset_download("antgoldbloom/us-eia-hourly-electricity-consumption")
    # Find first CSV in the folder
    for file in os.listdir(path):
        if file.endswith(".csv"):
            dataset_path = os.path.join(path, file)
            break

    # Load and basic cleaning
    df = pd.read_csv(dataset_path)

# %%
path = kagglehub.dataset_download("antgoldbloom/us-eia-hourly-electricity-consumption")
    # Find first CSV in the folder
for file in os.listdir(path):
    if file.endswith(".csv"):
        dataset_path = os.path.join(path, file)
        break

    # Load and basic cleaning
df = pd.read_csv(dataset_path)

# %%
df
# Out:
#                 Unnamed: 0                                               name  \
# 0          EBA.DUK-ALL.D.H  Demand for Duke Energy Carolinas (DUK), hourly...
# 1          EBA.EPE-ALL.D.H  Demand for El Paso Electric Company (EPE), hou...
# 2          EBA.FLA-ALL.D.H     Demand for Florida (region), hourly - UTC time
# 3          EBA.FPC-ALL.D.H  Demand for Duke Energy Florida, Inc. (FPC), ho...
# 4          EBA.FPL-ALL.D.H  Demand for Florida Power & Light Co. (FPL), ho...
# ...                    ...                                                ...
# 1150  EBA.SRP-ALL.NG.OIL.H  Net generation from petroleum for Salt River P...
# 1151     EBA.GRMA-ALL.TI.H  Total interchange for Gila River Power, LLC (G...
# 1152      EBA.SRP-PNM.ID.H  Actual Net Interchange for Salt River Project ...
# 1153    EBA.GRMA-AZPS.ID.H  Actual Net Interchange for Gila River Power, L...
# 1154    EBA.AZPS-GRMA.ID.H  Actual Net Interchange for Arizona Public Serv...
#
# ...
